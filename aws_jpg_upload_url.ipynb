# %%
#v3
#image upload perfect code


import os
import boto3
import pandas as pd
from datetime import datetime

# AWS Credentials
AWS_ACCESS_KEY_ID = "AKIAQ4WCASZZHAHYXDDA"
AWS_SECRET_ACCESS_KEY = "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"
AWS_DEFAULT_REGION = "ap-southeast-2"
AWS_BUCKET = "mydaybucketlive"

# S3 folder name
S3_FOLDER = "migration/"

# Directory containing the .jpg files
directory_path = r"E:\Upload AWS\Extracted_Files_236JPG"

# Initialize S3 client
s3_client = boto3.client(
    's3',
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    region_name=AWS_DEFAULT_REGION
)

# List to store file names and their corresponding URLs
data = []

# Check if the directory exists
if not os.path.exists(directory_path):
    print(f"Directory {directory_path} does not exist.")
else:
    print(f"Scanning directory: {directory_path}")

    # Upload files and generate object URLs
    files_found = False
    for filename in os.listdir(directory_path):
        # Process only .jpg files
        if filename.endswith(".jpg"):
            files_found = True
            file_path = os.path.join(directory_path, filename)

            try:
                # Define S3 key (path) for the file inside the 'live/Images/' folder
                s3_key = f"{S3_FOLDER}{filename}"

                # Upload file to S3 under the 'live/Images/' folder with correct Content-Type
                s3_client.upload_file(
                    file_path, 
                    AWS_BUCKET, 
                    s3_key,
                    ExtraArgs={'ContentType': 'image/jpeg'}
                )
                print(f"Uploaded {filename} to S3 bucket {AWS_BUCKET} in folder {S3_FOLDER}.")

                # Generate the object URL
                object_url = f"https://{AWS_BUCKET}.s3.{AWS_DEFAULT_REGION}.amazonaws.com/{s3_key}"

                # Append file name and object URL to the data list
                data.append({'File Name': filename, 'Object URL': object_url})
            
            except Exception as e:
                print(f"Error uploading {filename}: {str(e)}")

    if not files_found:
        print("No .jpg files found in the directory.")

    # If data is not empty, save to Excel
    if data:
        # Convert data to a DataFrame
        df = pd.DataFrame(data)

        # Define output Excel file path
        output_excel = os.path.join(directory_path, 's3_uploaded_files_jpg.xlsx')

        # Save to Excel
        df.to_excel(output_excel, index=False)
        print(f"Upload complete. Data saved to {output_excel}.")
    else:
        print("No files uploaded, Excel file was not generated.")
# Out:
# Scanning directory: E:\Upload AWS\Extracted_Files_236JPG
# Uploaded ,.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 0001.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 000c1f045cd410ae686452b6a19082e.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 002df49fa8ee4d2e3fdbf8748800231.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 00ac8b0cf6f7691c132acb782baa7ef.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 00bb070e107a99eb29259cad893a266.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 00d7ba35b3684f1ae70a39c54bdb781.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 01.08.2024_13.57.34.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 01.08.2024_16.29.30.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 01.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 011c1338075e97f50c8fae6b5f59a2e.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 015ebe398a12dfe0dc551e38be54965.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 0188a8cd539ee45f0c63a578a652ecf.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 01_1.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 0301_1.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 03272024_155215.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 038e214b1a13e1fe0cf7cfffd5dd54b.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 0517.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 05730dddba5f9075ad3307cff745d32.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 058c73681e19339c01996c60948ee3a.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded 05dcfe360e6074ecd685a6617336991.jpg to S3 bucket mydaybucketlive in folder migration/.
# Uploaded
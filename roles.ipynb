# %%
#roles

import pandas as pd
from datetime import datetime


roles_data = {
    'id': [1, 2, 3, 4],  # Auto-incremental ID
    'name': ['property manager', 'strata manager', 'property manager custom', 'Staff Manager'],
    'created_by': ['Admin', 'Admin', 'Admin', 'Admin'],  # 'Admin' for all
    'soft_delete': [0, 0, 0, 0],  # 0 for all
    'created_at': [datetime.now().strftime('%Y-%m-%d %H:%M:%S')] * 4,  # Current timestamp
    'updated_at': [datetime.now().strftime('%Y-%m-%d %H:%M:%S')] * 4  # Current timestamp
}


df_roles = pd.DataFrame(roles_data)


df_roles.to_excel('roles.xlsx', index=False)

print("roles.xlsx file has been created successfully!")
